# %%
import pandas as pd

# %%
# %cd data\LCarrollResearcherFormat_202201_csv
# Out:
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'data\\LCarrollResearcherFormat_202201_csv'
# C:\Users\micha\Documents\Studium\uni 2018\Semester 8\Data Librarian\2022_BdK6.5.3-P5_Gruppe_2\data\LCarrollResearcherFormat_202201_csv

# %%
title = pd.read_csv("titles.csv")

# %%
title
# Out:
#                                                   Title  \
# 0                     'Alice' contado aos mais pequenos
# 1                                  'Alice' on the stage
# 2                                       'Cello acrostic
# 3     'Endowment of the Greek Professorship.' [A pap...
# 4     'I am no sportsman' : the sporting worlds of L...
# ...                                                 ...
# 3424                                    Русский дневник
# 3425  Соня в царств� дива : the first Russian transl...
# 3426                                        アリス物語 : 初級用
# 3427                                 ユークリッドと彼の現代のライバルたち
# 3428                                         不思議の国のことば学
#
#                                            Other titles BL record ID  \
# 0                           Nursery 'Alice'. Portuguese    017471733
# 1     Alice's adventures in Wonderland : and, Throug...    018530771
# 2                                                   NaN    015576761
# ...

# %%
date = title['Date of creation/publication'] # nur die Spalte mit den Jahren

# %%
counts = pd.Series(date).value_counts().nlargest(5) # Zeigt die Top 5 der Jahre mit den meisten Publikationen
print(counts)
# Lösung der Frage 1
# Out:
# 2015    229
# 2016    164
# 2010    107
# 2018     99
# 2017     96
# Name: Date of creation/publication, dtype: int64
