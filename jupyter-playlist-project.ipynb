# %%
import pandas as pd
import csv

# %%
titles_datei = pd.read_csv("data/titles.csv")

# %%
df_date = titles_datei["Date of creation/publication"]

# %%
titles_datei
# Out:
#                                                   Title  \
# 0                     'Alice' contado aos mais pequenos
# 1                                  'Alice' on the stage
# 2                                       'Cello acrostic
# 3     'Endowment of the Greek Professorship.' [A pap...
# 4     'I am no sportsman' : the sporting worlds of L...
# ...                                                 ...
# 3424                                    Русский дневник
# 3425  Соня в царств� дива : the first Russian transl...
# 3426                                        アリス物語 : 初級用
# 3427                                 ユークリッドと彼の現代のライバルたち
# 3428                                         不思議の国のことば学
#
#                                            Other titles BL record ID  \
# 0                           Nursery 'Alice'. Portuguese    017471733
# 1     Alice's adventures in Wonderland : and, Throug...    018530771
# 2                                                   NaN    015576761
# 3                                              Appendix    002740146
# 4                                                   NaN    018790430
# ...                                                 ...          ...
# 3424  Dnevnik puteshestvii︠a︡ v Rossii︠u︡ v 1867 god...    016563612
# 3425  Alice's adventures in Wonderland. Russian, 187...    018263832
# 3426  Alice's adventures in Wonderland. Japanese ; A...    019064706
# 3427  Euclid and His Modern Rivals ; Yūkuriddo to ka...    017806486
# 3428                      Fushigi no kuni no kotobagaku    016402546
#
#      Type of resource                            Content type  \
# 0           Monograph  Language material ; Still image ; Text
# 1           Monograph                Language material ; Text
# 2           Monograph                           Notated music
# 3           Monograph                Language material ; Text
# 4           Monograph                Language material ; Text
# ...               ...                                     ...
# 3424        Monograph                Language material ; Text
# 3425        Monograph  Language material ; Still image ; Text
# 3426        Monograph                Language material ; Text
# 3427        Monograph                Language material ; Text
# 3428        Monograph                Language material ; Text
#
#         Material type BNB number Archival Resource Key  \
# 0              Volume  GBB5A5335                   NaN
# 1     Online resource  GBB7I3847                   NaN
# 2              Volume        NaN                   NaN
# 3              Volume        NaN                   NaN
# 4              Volume  GBB8L1066                   NaN
# ...               ...        ...                   ...
# 3424           Volume        NaN                   NaN
# 3425           Volume  GBB745467                   NaN
# 3426           Volume        NaN                   NaN
# 3427           Volume        NaN                   NaN
# 3428           Volume        NaN                   NaN
#
#                                ISBN                  Name  ...  \
# 0                     9781782011187        Carroll, Lewis  ...
# 1     9780141956732 ; 9781101487228        Carroll, Lewis  ...
# 2                     9781423483526    Del Tredici, David  ...
# 3                               NaN  University of Oxford  ...
# 4                               NaN            Bale, John  ...
# ...                             ...                   ...  ...
# 3424  9785901805602 ; 9785912741951        Carroll, Lewis  ...
# 3425                  9781782011989        Carroll, Lewis  ...
# 3426                            NaN        Carroll, Lewis  ...
# 3427                  9784535798038                   NaN  ...
# 3428                  9784327450830                   NaN  ...
#
#      Date of creation/publication Edition  \
# 0                            2015     NaN
# 1                            1998     NaN
# 2                            2009     NaN
# 3                            1940     NaN
# 4                            2017     NaN
# ...                           ...     ...
# 3424                         2013     NaN
# 3425                         2017     NaN
# 3426                         1927     NaN
# 3427                         2016     NaN
# 3428                         1991     NaN
#
#                                    Physical description Dewey classification  \
# 0           xxix, 71 pages, colour illustrations, 22 cm                823.8
# 1     1 online resource (lxxx, 356 pages), illustrat...                823.8
# 2                               4 pages of music, 31 cm                787.4
# 3                                                   NaN                  NaN
# 4       334 pages, black and white illustrations, 21 cm                823.8
# ...                                                 ...                  ...
# 3424  416 pages, 24 unnumbered pages of plates, illu...                  NaN
# 3425  xlv, 120 pages, black and white illustrations,...                823.8
# 3426                    254 pages, illustrations, 22 cm                  NaN
# 3427                                   331 pages, 21 cm                  NaN
# 3428                                   228 pages, 20 cm                  NaN
#
#           BL shelfmark                                             Topics  \
# 0                  NaN         Alice, (Fictitious character from Carroll)
# 1        ELD.DS.197483  FICTION / Fantasy / General ; Fantasy fiction,...
# 2           H06/.12042                                        Cello music
# 3            8365.g.23                                                NaN
# 4     YKL.2018.a.21888  Carroll, Lewis, 1832-1898 ; Sports in literatu...
# ...                ...                                                ...
# 3424     YF.2014.a.942  Children's literature, English ; Russia--Socia...
# 3425               NaN  Alice, (Fictitious character from Carroll)--Ju...
# 3426       ORB.30/8712                                                NaN
# 3427     JPN.2016.a.58                            kikagaku ; 幾何学 ; Euclid
# 3428    JPN.1991.a.184  Eigo--Kenkyū Shidō ; Eigo--Kaishaku ; 英語--研究・指...
#
#                              Genre   Languages  \
# 0               Children's fiction  Portuguese
# 1                          Fiction     English
# 2                              NaN         NaN
# 3                              NaN     English
# 4                              NaN     English
# ...                            ...         ...
# 3424                         Diary     Russian
# 3425  Children's fiction ; Fantasy     Russian
# 3426                           NaN    Japanese
# 3427                           NaN    Japanese
# 3428                           NaN    Japanese
#
#                                                   Notes Provenance
# 0                           Translated from the English        NaN
# 1     'Includes the manuscript version of Alice's ad...        NaN
# 2     'Final Alice' is the fifth of six large works ...        NaN
# 3                            A photostatic reproduction        NaN
# 4                                                   NaN        NaN
# ...                                                 ...        ...
# 3424                                                NaN        NaN
# 3425  Text based on the original Russian edition of ...        NaN
# 3426                                                NaN        NaN
# 3427        原タイトル:Euclid and His Modern Rivals 原著第2版の翻訳        NaN
# 3428                                        文献:p225〜228        NaN
#
# [3429 rows x 29 columns]

# %%
df_date
# Out:
# 0       2015
# 1       1998
# 2       2009
# 3       1940
# 4       2017
#         ...
# 3424    2013
# 3425    2017
# 3426    1927
# 3427    2016
# 3428    1991
# Name: Date of creation/publication, Length: 3429, dtype: object

# %%
df_date.nlargest
# Out:
# <bound method Series.nlargest of 0       2015
# 1       1998
# 2       2009
# 3       1940
# 4       2017
#         ...
# 3424    2013
# 3425    2017
# 3426    1927
# 3427    2016
# 3428    1991
# Name: Date of creation/publication, Length: 3429, dtype: object>

# %%
df_date.values
# Out:
# array(['2015', '1998', '2009', ..., '1927', '2016', '1991'], dtype=object)

# %%
titles_datei["Date of creation/publication"].hist()
# Out:
# <AxesSubplot:>

# %%
df_date.hist()
# Out:
# <AxesSubplot:>

# %%
df_date_after_death = df_date >= "2000"

# %%
df_date_after_death
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 3424     True
# 3425     True
# 3426    False
# 3427     True
# 3428    False
# Name: Date of creation/publication, Length: 3429, dtype: bool

# %%
drei = titles_datei.groupby("Languages").sum()

# %%
drei
# Out:
#                                                                         Title  \
# Languages
# Afrikaans                   Alice deur die spieëlThrough the looking-glass...
# Altai                       Alice's adventures in Wonderland in AltaiAlice...
# Altaic languages            Alice's adventures in Wonderland in ShorAlice'...
# Altaic languages ; English  Alice's adventures in Wonderland in KhakasAlic...
# Aromanian                   Alice's adventures in Wonderland. AromanianPat...
# ...                                                                       ...
# Tsonga                      Alice's adventures in Wonderland. TsongaMbalan...
# Welsh                       Alice's adventures in WonderlandAlice's advent...
# Western Frisian             Alice yn wûnderlânAlice's adventures in Wonder...
# Yiddish                     Alice's adventures in WonderlandAlises avantur...
# Zulu                        Alice's adventures in Wonderland. ZuluU-Alice ...
#
#                                                                  Other titles  \
# Languages
# Afrikaans                   Through the looking-glass. AfrikaansAlice deur...
# Altai                       Alice's adventures in Wonderland. Altai ; Kaĭk...
# Altaic languages            Alice's adventures in Wonderland. ShorAlice's ...
# Altaic languages ; English  Alice's adventures in Wonderland. KhakassAlice...
# Aromanian                   Patimatli ali Alice tu Vãsilia ti CiudiiAlice'...
# ...                                                                       ...
# Tsonga                      Mbalango wa Alice eTikweni ra SwihlamarisoAlic...
# Welsh                       Alys yn Nhir SwynAnturiaethau Alys yng Ngwlad ...
# Western Frisian             Alice's adventures in Wonderland. FrisianAlice...
# Yiddish                     Alises avantures in Vunderland. EnglishAlice's...
# Zulu                        U-Alice ezweni LezimangaAlice's adventures in ...
#
#                                                                  BL record ID  \
# Languages
# Afrikaans                                                  000617620000617620
# Altai                           018016910018016910018016910018016910018016910
# Altaic languages                                           018189057018189057
# Altaic languages ; English                                 018263830018263830
# Aromanian                                                  017594044017594044
# ...                                                                       ...
# Tsonga                                                     017594045017594045
# Welsh                       0099416300081172130083203900155676330099416300...
# Western Frisian                                            000617481000617481
# Yiddish                                                    018904469018904469
# Zulu                                                       016873172016873172
#
#                                                              Type of resource  \
# Languages
# Afrikaans                                                  MonographMonograph
# Altai                           MonographMonographMonographMonographMonograph
# Altaic languages                                           MonographMonograph
# Altaic languages ; English                                 MonographMonograph
# Aromanian                                                  MonographMonograph
# ...                                                                       ...
# Tsonga                                                     MonographMonograph
# Welsh                       MonographMonographMonographMonographMonographM...
# Western Frisian                                            MonographMonograph
# Yiddish                                                    MonographMonograph
# Zulu                                                       MonographMonograph
#
#                                                                  Content type  \
# Languages
# Afrikaans                    Language material ; TextLanguage material ; Text
# Altai                       Language material ; Still image ; TextLanguage...
# Altaic languages            Language material ; Still image ; TextLanguage...
# Altaic languages ; English  Language material ; Still image ; TextLanguage...
# Aromanian                   Language material ; Still image ; TextLanguage...
# ...                                                                       ...
# Tsonga                      Language material ; Still image ; TextLanguage...
# Welsh                       Language material ; TextLanguage material ; Te...
# Western Frisian              Language material ; TextLanguage material ; Text
# Yiddish                     Language material ; Still image ; TextLanguage...
# Zulu                        Language material ; Still image ; TextLanguage...
#
#                                                                 Material type  \
# Languages
# Afrikaans                                                        VolumeVolume
# Altai                                          VolumeVolumeVolumeVolumeVolume
# Altaic languages                                                 VolumeVolume
# Altaic languages ; English                                       VolumeVolume
# Aromanian                                                        VolumeVolume
# ...                                                                       ...
# Tsonga                                                           VolumeVolume
# Welsh                       VolumeVolumeVolumeVolumeVolumeVolumeVolumeVolu...
# Western Frisian                                                  VolumeVolume
# Yiddish                                                          VolumeVolume
# Zulu                                                             VolumeVolume
#
#                                                                    BNB number  \
# Languages
# Afrikaans                                                                   0
# Altai                           GBB6D0427GBB6D0427GBB6D0427GBB6D0427GBB6D0427
# Altaic languages                                           GBB711003GBB711003
# Altaic languages ; English                                 GBB745465GBB745465
# Aromanian                                                  GBB5F4762GBB5F4762
# ...                                                                       ...
# Tsonga                                                     GBB5F4763GBB5F4763
# Welsh                       GB7306048GB8321880GB5313410GBB068548GB7306048G...
# Western Frisian                                                             0
# Yiddish                                                    GBB8A6203GBB8A6203
# Zulu                                                       GBB4A2287GBB4A2287
#
#                            Archival Resource Key  \
# Languages
# Afrikaans                                      0
# Altai                                          0
# Altaic languages                               0
# Altaic languages ; English                     0
# Aromanian                                      0
# ...                                          ...
# Tsonga                                         0
# Welsh                                          0
# Western Frisian                                0
# Yiddish                                        0
# Zulu                                           0
#
#                                                                          ISBN  \
# Languages
# Afrikaans                                                                   0
# Altai                       9781782011774978178201177497817820117749781782...
# Altaic languages                                   97817820118979781782011897
# Altaic languages ; English                         97817820117129781782011712
# Aromanian                                          97817820108149781782010814
# ...                                                                       ...
# Tsonga                                             97817820112319781782011231
# Welsh                       9780850881950978085088997097819048084669780850...
# Western Frisian                                                             0
# Yiddish                                            97817820119419781782011941
# Zulu                                               97817820106549781782010654
#
#                                                                          Name  \
# Languages
# Afrikaans                                        Carroll, LewisCarroll, Lewis
# Altai                       Carroll, LewisCarroll, LewisCarroll, LewisCarr...
# Altaic languages                                 Carroll, LewisCarroll, Lewis
# Altaic languages ; English                       Carroll, LewisCarroll, Lewis
# Aromanian                                        Carroll, LewisCarroll, Lewis
# ...                                                                       ...
# Tsonga                                           Carroll, LewisCarroll, Lewis
# Welsh                       Jenkins-Jones, AneurinCarroll, LewisCarroll, L...
# Western Frisian                                  Carroll, LewisCarroll, Lewis
# Yiddish                                          Carroll, LewisCarroll, Lewis
# Zulu                                             Carroll, LewisCarroll, Lewis
#
#                             ...  \
# Languages                   ...
# Afrikaans                   ...
# Altai                       ...
# Altaic languages            ...
# Altaic languages ; English  ...
# Aromanian                   ...
# ...                         ...
# Tsonga                      ...
# Welsh                       ...
# Western Frisian             ...
# Yiddish                     ...
# Zulu                        ...
#
#                                                                     Publisher  \
# Languages
# Afrikaans                                    Human & RousseauHuman & Rousseau
# Altai                                EvertypeEvertypeEvertypeEvertypeEvertype
# Altaic languages                                             EvertypeEvertype
# Altaic languages ; English                                   EvertypeEvertype
# Aromanian                                                    EvertypeEvertype
# ...                                                                       ...
# Tsonga                                                       EvertypeEvertype
# Welsh                       Gwasg GomerGwasg GomerGwasg GeeEvertypeGwasg G...
# Western Frisian                                                             0
# Yiddish                                                      EvertypeEvertype
# Zulu                                                         EvertypeEvertype
#
#                                         Date of creation/publication  \
# Languages
# Afrikaans                                                   19681968
# Altai                                           20162016201620162016
# Altaic languages                                            20192019
# Altaic languages ; English                                  20192019
# Aromanian                                                   20152015
# ...                                                              ...
# Tsonga                                                      20152015
# Welsh                       1973198219532010197319821953201019841984
# Western Frisian                                             19641964
# Yiddish                                                     20182018
# Zulu                                                        20142014
#
#                                                                       Edition  \
# Languages
# Afrikaans                                                                   0
# Altai                                                                       0
# Altaic languages                                                            0
# Altaic languages ; English                                                  0
# Aromanian                   Prota editsii = First editionProta editsii = F...
# ...                                                                       ...
# Tsonga                                                                      0
# Welsh                                                Argraffiad 1Argraffiad 1
# Western Frisian                                                             0
# Yiddish                                          Second editionSecond edition
# Zulu                                                                        0
#
#                                                          Physical description  \
# Languages
# Afrikaans                   138 pages, illustrations, 22 cm138 pages, illu...
# Altai                       xxi, 129 pages, black and white illustrations,...
# Altaic languages            xxxiii, 133 pages, black and white illustratio...
# Altaic languages ; English  xxv, 130 pages, black and white illustrations,...
# Aromanian                   viii, 121 pages, illustrations, 22 cmviii, 121...
# ...                                                                       ...
# Tsonga                      xii, 135 pages, illustrations, 22 cmxii, 135 p...
# Welsh                       18 pages, colour illustrations, 26 cm115 pages...
# Western Frisian             119 pages, illustrations (8°)119 pages, illust...
# Yiddish                     xii, 118 pages, black and white illustrations,...
# Zulu                        xiv, 139 pages, black and white illustrations,...
#
#                                                          Dewey classification  \
# Languages
# Afrikaans                                                                   0
# Altai                                               823.8823.8823.8823.8823.8
# Altaic languages                                                   823.8823.8
# Altaic languages ; English                                         823.8823.8
# Aromanian                                                          823.8823.8
# ...                                                                       ...
# Tsonga                                                             823.8823.8
# Welsh                       891.6632823.8891.663823.8891.6632823.8891.6638...
# Western Frisian                                                             0
# Yiddish                                                            823.9823.9
# Zulu                                                               823.8823.8
#
#                                                                  BL shelfmark  \
# Languages
# Afrikaans                                                X.990/5059X.990/5059
# Altai                                                                       0
# Altaic languages                                                            0
# Altaic languages ; English                                                  0
# Aromanian                                                                   0
# ...                                                                       ...
# Tsonga                                                                      0
# Welsh                       X.992/1279X.990/2020012836.c.24YK.2011.a.41972...
# Western Frisian                                            X.998/183X.998/183
# Yiddish                                                                     0
# Zulu                                                                        0
#
#                                                                        Topics  \
# Languages
# Afrikaans                                                                   0
# Altai                       Alice, (Fictitious character from Carroll)--Ju...
# Altaic languages            Alice, (Fictitious character from Carroll)--Ju...
# Altaic languages ; English  Alice, (Fictitious character from Carroll)--Ju...
# Aromanian                   Alice, (Fictitious character from Carroll)Alic...
# ...                                                                       ...
# Tsonga                      Alice, (Fictitious character from Carroll)Alic...
# Welsh                       Children's stories in Welsh, 1600---Texts (inc...
# Western Frisian                                                             0
# Yiddish                     Alice, (Fictitious character from Carroll)--Fi...
# Zulu                        Alice (Fictitious character from Carroll)--Juv...
#
#                                                                         Genre  \
# Languages
# Afrikaans                                                                   0
# Altai                       Children's fictionChildren's fictionChildren's...
# Altaic languages                         Children's fictionChildren's fiction
# Altaic languages ; English  Children's fiction ; FantasyChildren's fiction...
# Aromanian                                Children's fictionChildren's fiction
# ...                                                                       ...
# Tsonga                                   Children's fictionChildren's fiction
# Welsh                       Children's fiction ; FantasyChildren's fiction...
# Western Frisian                                                             0
# Yiddish                                    Fantasy ; FictionFantasy ; Fiction
# Zulu                                     Children's fictionChildren's fiction
#
#                                                                         Notes  \
# Languages
# Afrikaans                                                                   0
# Altai                       Title transliterated ; Translated from the Eng...
# Altaic languages            Translated from the EnglishTranslated from the...
# Altaic languages ; English                                                  0
# Aromanian                   Translated from the EnglishTranslated from the...
# ...                                                                       ...
# Tsonga                      Translated from the EnglishTranslated from the...
# Welsh                                                                       0
# Western Frisian             Oersetting: Tiny Mulder. Mei de yllustraesjes ...
# Yiddish                     Translated from the EnglishTranslated from the...
# Zulu                        Translated from the EnglishTranslated from the...
#
#                            Provenance
# Languages
# Afrikaans                           0
# Altai                               0
# Altaic languages                    0
# Altaic languages ; English          0
# Aromanian                           0
# ...                               ...
# Tsonga                              0
# Welsh                               0
# Western Frisian                     0
# Yiddish                             0
# Zulu                                0
#
# [96 rows x 28 columns]
