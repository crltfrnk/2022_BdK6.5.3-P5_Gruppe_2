# %%
import pandas as pd
import json

# %%
data = json.load(open("data/mpd.slice.0-999.json"))
df = pd.DataFrame(data["playlists"])

# %%
df
# Out:
#                  name collaborative  pid  modified_at  num_tracks  num_albums  \
# 0          Throwbacks         false    0   1493424000          52          47
# 1    Awesome Playlist         false    1   1506556800          39          23
# 2             korean          false    2   1505692800          64          51
# 3                 mat         false    3   1501027200         126         107
# 4                 90s         false    4   1401667200          17          16
# ..                ...           ...  ...          ...         ...         ...
# 995               old         false  995   1507852800          41          40
# 996              Daze         false  996   1479254400          17          17
# 997               rap         false  997   1410307200         119          98
# 998           Country         false  998   1507939200         108          75
# 999   thinking of you         false  999   1507766400          44          43
#
# ...

# %%
df["tracks"]
# die tracks sind einzelne Dictonaries im "playlists"-dictonary
# Out:
# 0      [{'pos': 0, 'artist_name': 'Missy Elliott', 't...
# 1      [{'pos': 0, 'artist_name': 'Survivor', 'track_...
# 2      [{'pos': 0, 'artist_name': 'Hoody', 'track_uri...
# 3      [{'pos': 0, 'artist_name': 'Camille Saint-Saën...
# 4      [{'pos': 0, 'artist_name': 'The Smashing Pumpk...
#                              ...
# 995    [{'pos': 0, 'artist_name': 'Katrina', 'track_u...
# 996    [{'pos': 0, 'artist_name': 'PARTYNEXTDOOR', 't...
# 997    [{'pos': 0, 'artist_name': 'LoveRance', 'track...
# 998    [{'pos': 0, 'artist_name': 'Hunter Hayes', 'tr...
# 999    [{'pos': 0, 'artist_name': 'Pvris', 'track_uri...
# Name: tracks, Length: 1000, dtype: object
